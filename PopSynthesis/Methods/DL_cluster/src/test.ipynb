# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
df_p = pd.read_csv("../data/test_pp.csv")
df_h = pd.read_csv("../data/test_hh.csv")

# %%
# Out:
#          Unnamed: 0   sex    age fulltimework parttimework casualwork anywork
# 0                 0  male   5-14            N            N          N       N  \
# 1                 1  male   5-14            N            N          N       N
# 2                 2  male   5-14            N            N          N       N
# 3                 3  male   5-14            N            N          N       N
# 4                 4  male   5-14            N            N          N       N
# ...             ...   ...    ...          ...          ...        ...     ...
# 5244327      168907  male  20-24            N            Y          N       Y
# 5244328      168908  male  20-24            N            Y          N       Y
# 5244329      168909  male  20-24            N            Y          N       Y
# 5244330      168910  male  20-24            N            Y          N       Y
# 5244331      168911  male  20-24            N            Y          N       Y
#
#            SA3
# 0        20301
# 1        20301
# 2        20301
# 3        20301
# 4        20301
# ...        ...
# 5244327  21402
# 5244328  21402
# 5244329  21402
# 5244330  21402
# 5244331  21402
#
# [5244332 rows x 8 columns]
