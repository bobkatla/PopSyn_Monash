# %%
import os
from glob import glob
import pandas as pd
import numpy as np

from PopSynthesis.Methods.connect_HH_PP.paras_dir import processed_data, output_dir
from PopSynthesis.Methods.connect_HH_PP.scripts.const import *

# %%
del_df = []
for file in glob(os.path.join(processed_data, "del*")):
    df = pd.read_csv(file)
    del_df.append(df)
del_df = pd.concat(del_df)
del_df
# Out:
#           hhid    age sex          persinc     nolicence anywork  Spouse  \
# 0         2137  30-39   M  Negative Income  Some Licence       Y       0
# 1         6911  30-39   M  Negative Income  Some Licence       Y       1
# 2        26615  30-39   M  Negative Income  Some Licence       Y       1
# 3        34262  30-39   M  Negative Income  Some Licence       Y       1
# 4        37389  30-39   M  Negative Income  Some Licence       Y       1
# ...        ...    ...  ..              ...           ...     ...     ...
# 14050   275748   100+   M      $2000+ p.w.    No Licence       Y       1
# 14051  2120625   100+   M    $300-399 p.w.  Some Licence       Y       1
# 14052  1275415   100+   M    $400-599 p.w.    No Licence       Y       1
# 14053   841088   100+   F  $1000-1249 p.w.    No Licence       Y       1
# 14054   694542  10-19   F    $800-999 p.w.  Some Licence       N       1
#
#        Child  Grandchild  Others
# 0          3           0       0
# 1          1           0       0
# 2          1           0       0
# 3          2           0       0
# 4          1           0       0
# ...      ...         ...     ...
# 14050      0           0       0
# 14051      1           0       0
# 14052      1           1       1
# 14053      1           2       0
# 14054      0           0       0
#
# [40508 rows x 10 columns]

# %%
ls_hhid = del_df["hhid"].unique()
ls_hhid
# Out:
# array([  2137,   6911,  26615, ..., 555474, 275748, 694542], dtype=int64)

# %%
main_pp_df_hh = pd.read_csv(os.path.join(processed_data, "SynPop_hh_main_POA.csv"))
main_pp_df_hh["hhid"] = main_pp_df_hh.index
main_pp_df_hh
# Out:
#                  dwelltype         owndwell      hhinc totalvehs  Spouse  \
# 0           Separate House  Being Purchased  1250-1499        4+       1
# 1           Separate House      Fully Owned  3500-3999        4+       1
# 2           Separate House  Being Purchased    650-799        4+       1
# 3           Separate House  Being Purchased  4000-4499        4+       1
# 4           Separate House  Being Purchased  1250-1499        4+       1
# ...                    ...              ...        ...       ...     ...
# 2801757  Terrace/Townhouse     Being Rented    650-799         1       0
# 2801758     Separate House  Being Purchased    150-299         3       0
# 2801759     Separate House      Fully Owned  2500-2999         1       1
# 2801760     Separate House  Being Purchased  3000-3499         2       1
# 2801761     Separate House      Fully Owned    650-799         2       1
#
#          Child  Others  Grandchild    age sex          persinc     nolicence  \
# 0            0       0           0  80-89   M    $200-299 p.w.  Some Licence
# 1            2       0           0  50-59   F  $1500-1999 p.w.  Some Licence
# 2            2       0           0  50-59   M    $600-799 p.w.  Some Licence
# 3            2       0           0  30-39   M      $2000+ p.w.  Some Licence
# 4            2       0           0  40-49   M    $800-999 p.w.  Some Licence
# ...        ...     ...         ...    ...  ..              ...           ...
# 2801757      1       2           0  30-39   F    $300-399 p.w.  Some Licence
# 2801758      0       1           0  20-29   F    $200-299 p.w.  Some Licence
# 2801759      2       0           0  40-49   M  $1500-1999 p.w.  Some Licence
# 2801760      1       0           0  30-39   M      $2000+ p.w.  Some Licence
# 2801761      0       0           0  70-79   F    $300-399 p.w.  Some Licence
#
#         anywork   POA     hhid
# 0             N  3000        0
# 1             Y  3000        1
# 2             Y  3000        2
# 3             Y  3000        3
# 4             N  3000        4
# ...         ...   ...      ...
# 2801757       Y  3996  2801757
# 2801758       Y  3996  2801758
# 2801759       Y  3996  2801759
# 2801760       Y  3996  2801760
# 2801761       N  3996  2801761
#
# [2801762 rows x 15 columns]

# %%
hh_cols = [x for x in HH_ATTS] + ["POA"]
hh_df = main_pp_df_hh[hh_cols]
hh_df
# Out:
#             hhid          dwelltype         owndwell      hhinc totalvehs  \
# 0              0     Separate House  Being Purchased  1250-1499        4+
# 1              1     Separate House      Fully Owned  3500-3999        4+
# 2              2     Separate House  Being Purchased    650-799        4+
# 3              3     Separate House  Being Purchased  4000-4499        4+
# 4              4     Separate House  Being Purchased  1250-1499        4+
# ...          ...                ...              ...        ...       ...
# 2801757  2801757  Terrace/Townhouse     Being Rented    650-799         1
# 2801758  2801758     Separate House  Being Purchased    150-299         3
# 2801759  2801759     Separate House      Fully Owned  2500-2999         1
# 2801760  2801760     Separate House  Being Purchased  3000-3499         2
# 2801761  2801761     Separate House      Fully Owned    650-799         2
#
#           POA
# 0        3000
# 1        3000
# 2        3000
# 3        3000
# 4        3000
# ...       ...
# 2801757  3996
# 2801758  3996
# 2801759  3996
# 2801760  3996
# 2801761  3996
#
# [2801762 rows x 6 columns]

# %%
pp_cols = [x for x in PP_ATTS if x not in ["persid", "relationship"]]
pp_main_df = main_pp_df_hh[pp_cols]
pp_main_df["relationship"] = "Main"
pp_main_df
# Out:
# C:\Users\dlaa0001\AppData\Local\Temp\ipykernel_12112\3161071396.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pp_main_df["relationship"] = "Main"
#             hhid    age sex          persinc     nolicence anywork  \
# 0              0  80-89   M    $200-299 p.w.  Some Licence       N
# 1              1  50-59   F  $1500-1999 p.w.  Some Licence       Y
# 2              2  50-59   M    $600-799 p.w.  Some Licence       Y
# 3              3  30-39   M      $2000+ p.w.  Some Licence       Y
# 4              4  40-49   M    $800-999 p.w.  Some Licence       N
# ...          ...    ...  ..              ...           ...     ...
# 2801757  2801757  30-39   F    $300-399 p.w.  Some Licence       Y
# 2801758  2801758  20-29   F    $200-299 p.w.  Some Licence       Y
# 2801759  2801759  40-49   M  $1500-1999 p.w.  Some Licence       Y
# 2801760  2801760  30-39   M      $2000+ p.w.  Some Licence       Y
# 2801761  2801761  70-79   F    $300-399 p.w.  Some Licence       N
#
#         relationship
# 0               Main
# 1               Main
# 2               Main
# 3               Main
# 4               Main
# ...              ...
# 2801757         Main
# 2801758         Main
# 2801759         Main
# 2801760         Main
# 2801761         Main
#
# [2801762 rows x 7 columns]

# %%
all_df_pp = []
for file in glob(os.path.join(processed_data, "pp*")):
    df = pd.read_csv(file)
    rela = file.split("\\")[-1].split("_")[-1].split(".")[0]
    cols_main = [f"{x}_main" for x in PP_ATTS if x not in["relationship", "persid", "hhid"]]
    rename_cols = {f"{name}_{rela}": name for name in PP_ATTS if name not in["relationship", "persid", "hhid"]}
    df = df.drop(columns=cols_main)
    df = df.rename(columns=rename_cols)
    all_df_pp.append(df)
all_df_pp = pd.concat(all_df_pp)
all_df_pp
# Out:
#            age sex          persinc     nolicence anywork     hhid  \
# 0        20-29   F    $200-299 p.w.  Some Licence       N  1445963
# 1        20-29   F    $200-299 p.w.  Some Licence       N  1742925
# 2        20-29   F    $200-299 p.w.  Some Licence       N  2279711
# 3        20-29   F    $200-299 p.w.  Some Licence       N  2745384
# 4          0-9   M      $1-199 p.w.    No Licence       N    77854
# ...        ...  ..              ...           ...     ...      ...
# 1765937  80-89   F  $1500-1999 p.w.  Some Licence       N  2775742
# 1765938  80-89   F    $200-299 p.w.  Some Licence       N  2778192
# 1765939  80-89   F  $1500-1999 p.w.  Some Licence       N  2793444
# 1765940  80-89   F      Zero Income  Some Licence       N  2793616
# 1765941  80-89   F      Zero Income  Some Licence       N  2800039
#
#         relationship
# 0              Child
# 1              Child
# 2              Child
# 3              Child
# 4              Child
# ...              ...
# 1765937       Spouse
# 1765938       Spouse
# 1765939       Spouse
# 1765940       Spouse
# 1765941       Spouse
#
# [4331327 rows x 7 columns]

# %%
final_pp_df = pd.concat([all_df_pp, pp_main_df])
final_pp_df = final_pp_df[~final_pp_df["hhid"].isin(del_df["hhid"])]
final_pp_df
# Out:
#            age sex          persinc     nolicence anywork     hhid  \
# 2        20-29   F    $200-299 p.w.  Some Licence       N  2279711
# 4          0-9   M      $1-199 p.w.    No Licence       N    77854
# 5        10-19   F      Zero Income    No Licence       N    78610
# 6        10-19   F      Zero Income    No Licence       N    88565
# 7          0-9   M      $1-199 p.w.    No Licence       N    93232
# ...        ...  ..              ...           ...     ...      ...
# 2801757  30-39   F    $300-399 p.w.  Some Licence       Y  2801757
# 2801758  20-29   F    $200-299 p.w.  Some Licence       Y  2801758
# 2801759  40-49   M  $1500-1999 p.w.  Some Licence       Y  2801759
# 2801760  30-39   M      $2000+ p.w.  Some Licence       Y  2801760
# 2801761  70-79   F    $300-399 p.w.  Some Licence       N  2801761
#
#         relationship
# 2              Child
# 4              Child
# 5              Child
# 6              Child
# 7              Child
# ...              ...
# 2801757         Main
# 2801758         Main
# 2801759         Main
# 2801760         Main
# 2801761         Main
#
# [7058113 rows x 7 columns]

# %%
final_pp_df.to_csv(os.path.join(output_dir, "POA","syn_pp_final.csv"), index=False)

# %%
hh_df_rm = hh_df[~hh_df["hhid"].isin(del_df["hhid"])]
hh_df_rm
# Out:
#             hhid          dwelltype         owndwell      hhinc totalvehs  \
# 0              0     Separate House  Being Purchased  1250-1499        4+
# 1              1     Separate House      Fully Owned  3500-3999        4+
# 2              2     Separate House  Being Purchased    650-799        4+
# 3              3     Separate House  Being Purchased  4000-4499        4+
# 4              4     Separate House  Being Purchased  1250-1499        4+
# ...          ...                ...              ...        ...       ...
# 2801757  2801757  Terrace/Townhouse     Being Rented    650-799         1
# 2801758  2801758     Separate House  Being Purchased    150-299         3
# 2801759  2801759     Separate House      Fully Owned  2500-2999         1
# 2801760  2801760     Separate House  Being Purchased  3000-3499         2
# 2801761  2801761     Separate House      Fully Owned    650-799         2
#
#           POA
# 0        3000
# 1        3000
# 2        3000
# 3        3000
# 4        3000
# ...       ...
# 2801757  3996
# 2801758  3996
# 2801759  3996
# 2801760  3996
# 2801761  3996
#
# [2765617 rows x 6 columns]

# %%
counting_pp_hh = final_pp_df["hhid"].value_counts()

hh_df_rm["hhsize"] = hh_df_rm.apply(lambda r: counting_pp_hh[r["hhid"]], axis=1)
hh_df_rm["hhsize"].unique()
# Out:
# C:\Users\dlaa0001\AppData\Local\Temp\ipykernel_12112\4190372236.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh_df_rm["hhsize"] = hh_df_rm.apply(lambda r: counting_pp_hh[r["hhid"]], axis=1)
# array([ 5,  6,  2,  4,  3,  1,  7,  8, 11,  9, 10, 13, 12, 14, 15],
#       dtype=int64)

# %%
hh_df_rm.to_csv(os.path.join(output_dir, "POA","syn_hh_final.csv"), index=False)
