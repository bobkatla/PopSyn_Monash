# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt

from PopSynthesis.Methods.BN.utils.learn_BN import learn_struct_BN_score
from pgmpy.sampling import BayesianModelSampling
from pgmpy.estimators import BayesianEstimator

from PopSynthesis.Methods.connect_HH_PP.paras_dir import processed_data, geo_lev, output_dir

# %% [markdown]
# # General usage, mainly for producing graphs

# %%
pp_state_names = None
with open(os.path.join(processed_data, 'dict_pp_states.pickle'), 'rb') as handle:
    pp_state_names = pickle.load(handle)
hh_state_names = None
with open(os.path.join(processed_data, 'dict_hh_states.pickle'), 'rb') as handle:
    hh_state_names = pickle.load(handle)
state_names = hh_state_names | pp_state_names

# %%
#learning to get the HH only with main person
df_seed = pd.read_csv(os.path.join(processed_data, "connect_hh_main.csv"))
# drop all the ids as they are not needed for in BN learning
id_cols = [x for x in df_seed.columns if "hhid" in x or "persid" in x] + ["nolicence"]
df_seed = df_seed.drop(columns=id_cols)
# pool_hh_main = get_pool(df_seed, state_names, pool_sz=POOL_SZ)
model = learn_struct_BN_score(df_seed, show_struct=True, state_names=state_names)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
#learning to get the HH only with main person
df_seed = pd.read_csv(os.path.join(processed_data, "connect_main_Spouse.csv"))
# drop all the ids as they are not needed for in BN learning
id_cols = [x for x in df_seed.columns if "hhid" in x or "persid" in x or "nolicence" in x]
df_seed = df_seed.drop(columns=id_cols)
# pool_hh_main = get_pool(df_seed, state_names, pool_sz=POOL_SZ)
model = learn_struct_BN_score(df_seed, show_struct=True)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
#learning to get the HH only with main person
df_seed = pd.read_csv(os.path.join(processed_data, "connect_main_Child.csv"))
# drop all the ids as they are not needed for in BN learning
id_cols = [x for x in df_seed.columns if "hhid" in x or "persid" in x or "nolicence" in x]
df_seed = df_seed.drop(columns=id_cols)
# pool_hh_main = get_pool(df_seed, state_names, pool_sz=POOL_SZ)
model = learn_struct_BN_score(df_seed, show_struct=True)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
#learning to get the HH only with main person
df_seed = pd.read_csv(os.path.join(processed_data, "connect_main_Grandchild.csv"))
# drop all the ids as they are not needed for in BN learning
id_cols = [x for x in df_seed.columns if "hhid" in x or "persid" in x or "nolicence" in x]
df_seed = df_seed.drop(columns=id_cols)
# pool_hh_main = get_pool(df_seed, state_names, pool_sz=POOL_SZ)
model = learn_struct_BN_score(df_seed, show_struct=True)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
#learning to get the HH only with main person
df_seed = pd.read_csv(os.path.join(processed_data, "connect_main_Others.csv"))
# drop all the ids as they are not needed for in BN learning
id_cols = [x for x in df_seed.columns if "hhid" in x or "persid" in x or "nolicence" in x]
df_seed = df_seed.drop(columns=id_cols)
# pool_hh_main = get_pool(df_seed, state_names, pool_sz=POOL_SZ)
model = learn_struct_BN_score(df_seed, show_struct=True)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
